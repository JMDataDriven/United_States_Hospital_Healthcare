# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# ## Import Dataframes

# %%
# Define Path
path = r'C:\Users\jmiel\JENNY_STUFF\MY_DOCS\CareerFoundry\U.S. Hospitals'

# Importing Hospital_General_Information os
hospital_general_information = pd.read_csv(os.path.join(path, 'Data','Prepared Data', 'Hospital_General_Information_Clean.csv'), index_col = False)

# Importing Hospital_Locations os 
hospital_locations = pd.read_csv(os.path.join(path, 'Data','Prepared Data', 'Hospital_Locations_Clean.csv'), index_col = False)

# %% [markdown]
# ## Exploring Relationships

# %%
# Create a subset to include neccesary columns for correlation matrix 
hospital_general_information_subset = hospital_general_information[['hospital_overall_rating', 'emergency_services', 'hospital_type', 'mortality_national_comparison', 'safety_of_care_national_comparison', 'readmission_national_comparison', 'patient_experience_national_comparison', 'effectiveness_of_care_national_comparison', 'timeliness_of_care_national_comparison']].copy()

# %%
# Verify output 
hospital_general_information_subset
# Out:
#       hospital_overall_rating  emergency_services              hospital_type  \
# 0                         3.0                True       Acute Care Hospitals
# 1                         4.0                True       Acute Care Hospitals
# 2                         3.0                True       Acute Care Hospitals
# 3                         3.0                True       Acute Care Hospitals
# 4                         3.0                True       Acute Care Hospitals
# ...                       ...                 ...                        ...
# 4813                      3.0                True  Critical Access Hospitals
# 4814                      4.0                True       Acute Care Hospitals
# 4815                      NaN                True  Critical Access Hospitals
# 4816                      NaN                True       Acute Care Hospitals
# 4817                      2.0                True       Acute Care Hospitals
#
# ...

# %%
hospital_general_information_subset['hospital_type'].value_counts()
# Out:
# hospital_type
# Acute Care Hospitals         3382
# Critical Access Hospitals    1337
# Childrens                      99
# Name: count, dtype: int64

# %%
# In subset, replace hospital_type with numerical value for purpose of analysis
hospital_general_information_subset['hospital_type'].replace('Acute Care Hospitals', '1', inplace = True)
hospital_general_information_subset['hospital_type'].replace('Critical Access Hospitals', '2', inplace = True)
hospital_general_information_subset['hospital_type'].replace('Childrens', '3', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\3242883762.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['hospital_type'].replace('Acute Care Hospitals', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\3242883762.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hospital_general_information_subset['hospital_type'].value_counts()
# Out:
# hospital_type
# 1    3382
# 2    1337
# 3      99
# Name: count, dtype: int64

# %%
hospital_general_information_subset['mortality_national_comparison'].value_counts()
# Out:
# mortality_national_comparison
# Same as the National average    2736
# Not Available                   1337
# Above the National average       402
# Below the National average       343
# Name: count, dtype: int64

# %%
# In mortality_national_comparison, replace with numerical value
hospital_general_information_subset['mortality_national_comparison'].replace('Above the National average', '1', inplace = True)
hospital_general_information_subset['mortality_national_comparison'].replace('Same as the National average', '2', inplace = True)
hospital_general_information_subset['mortality_national_comparison'].replace('Below the National average', '3', inplace = True)
hospital_general_information_subset['mortality_national_comparison'].replace('Not Available', '4', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\1117832501.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['mortality_national_comparison'].replace('Above the National average', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\1117832501.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Check to checked implemented changes
hospital_general_information_subset['mortality_national_comparison'].value_counts()
# Out:
# mortality_national_comparison
# 2    2736
# 4    1337
# 1     402
# 3     343
# Name: count, dtype: int64

# %%
hospital_general_information_subset['safety_of_care_national_comparison'].value_counts()
# Out:
# safety_of_care_national_comparison
# Not Available                   1892
# Same as the National average    1448
# Above the National average       805
# Below the National average       673
# Name: count, dtype: int64

# %%
# In safety_of_care_national_comparison column replace with numerical values for analysis purposes
hospital_general_information_subset['safety_of_care_national_comparison'].replace('Above the National average', '1', inplace = True)
hospital_general_information_subset['safety_of_care_national_comparison'].replace('Same as the National average', '2', inplace = True)
hospital_general_information_subset['safety_of_care_national_comparison'].replace('Below the National average', '3', inplace = True)
hospital_general_information_subset['safety_of_care_national_comparison'].replace('Not Available', '4', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\2554086295.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['safety_of_care_national_comparison'].replace('Above the National average', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\2554086295.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hospital_general_information_subset['safety_of_care_national_comparison'].value_counts()
# Out:
# safety_of_care_national_comparison
# 4    1892
# 2    1448
# 1     805
# 3     673
# Name: count, dtype: int64

# %%
hospital_general_information_subset['readmission_national_comparison'].value_counts()
# Out:
# readmission_national_comparison
# Same as the National average    2133
# Not Available                   1002
# Below the National average       872
# Above the National average       811
# Name: count, dtype: int64

# %%
# In readmission_naitonal_comparison column, replace with numerical values 
hospital_general_information_subset['readmission_national_comparison'].replace('Above the National average', '1', inplace = True)
hospital_general_information_subset['readmission_national_comparison'].replace('Same as the National average', '2', inplace = True)
hospital_general_information_subset['readmission_national_comparison'].replace('Below the National average', '3', inplace = True)
hospital_general_information_subset['readmission_national_comparison'].replace('Not Available', '4', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\3256463114.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['readmission_national_comparison'].replace('Above the National average', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\3256463114.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hospital_general_information_subset['readmission_national_comparison'].value_counts()
# Out:
# readmission_national_comparison
# 2    2133
# 4    1002
# 3     872
# 1     811
# Name: count, dtype: int64

# %%
hospital_general_information_subset['patient_experience_national_comparison'].value_counts()
# Out:
# patient_experience_national_comparison
# Not Available                   1355
# Above the National average      1202
# Same as the National average    1161
# Below the National average      1100
# Name: count, dtype: int64

# %%
# In patient_experience_national_comparison column, replace variables to numerical values 
hospital_general_information_subset['patient_experience_national_comparison'].replace('Above the National average', '1', inplace = True)
hospital_general_information_subset['patient_experience_national_comparison'].replace('Same as the National average', '2', inplace = True)
hospital_general_information_subset['patient_experience_national_comparison'].replace('Below the National average', '3', inplace = True)
hospital_general_information_subset['patient_experience_national_comparison'].replace('Not Available', '4', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\2496311410.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['patient_experience_national_comparison'].replace('Above the National average', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\2496311410.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hospital_general_information_subset['patient_experience_national_comparison'].value_counts()
# Out:
# patient_experience_national_comparison
# 4    1355
# 1    1202
# 2    1161
# 3    1100
# Name: count, dtype: int64

# %%
hospital_general_information_subset['effectiveness_of_care_national_comparison'].value_counts()
# Out:
# effectiveness_of_care_national_comparison
# Same as the National average    2196
# Not Available                   1116
# Above the National average       997
# Below the National average       509
# Name: count, dtype: int64

# %%
# In effectiveness_of_care_national_comparison column, replace variables with numeric value
hospital_general_information_subset['effectiveness_of_care_national_comparison'].replace('Above the National average', '1', inplace = True)
hospital_general_information_subset['effectiveness_of_care_national_comparison'].replace('Same as the National average', '2', inplace = True)
hospital_general_information_subset['effectiveness_of_care_national_comparison'].replace('Below the National average', '3', inplace = True)
hospital_general_information_subset['effectiveness_of_care_national_comparison'].replace('Not Available', '4', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\2013171502.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['effectiveness_of_care_national_comparison'].replace('Above the National average', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\2013171502.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hospital_general_information_subset['effectiveness_of_care_national_comparison'].value_counts()
# Out:
# effectiveness_of_care_national_comparison
# 2    2196
# 4    1116
# 1     997
# 3     509
# Name: count, dtype: int64

# %%
hospital_general_information_subset['timeliness_of_care_national_comparison'].value_counts()
# Out:
# timeliness_of_care_national_comparison
# Same as the National average    1481
# Not Available                   1331
# Above the National average      1103
# Below the National average       903
# Name: count, dtype: int64

# %%
# In timeliness_of_care_national_comparison column, replace variables with numeric values 
hospital_general_information_subset['timeliness_of_care_national_comparison'].replace('Above the National average', '1', inplace = True)
hospital_general_information_subset['timeliness_of_care_national_comparison'].replace('Same as the National average', '2', inplace = True)
hospital_general_information_subset['timeliness_of_care_national_comparison'].replace('Below the National average', '3', inplace = True)
hospital_general_information_subset['timeliness_of_care_national_comparison'].replace('Not Available', '4', inplace = True)
# Out:
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\136213141.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_general_information_subset['timeliness_of_care_national_comparison'].replace('Above the National average', '1', inplace = True)
# C:\Users\jmiel\AppData\Local\Temp\ipykernel_21132\136213141.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
hospital_general_information_subset['timeliness_of_care_national_comparison'].value_counts()
# Out:
# timeliness_of_care_national_comparison
# 2    1481
# 4    1331
# 1    1103
# 3     903
# Name: count, dtype: int64

# %%
# Create a correlation matrix of necessary columns
hospital_general_information_subset.corr()
# Out:
#                                            hospital_overall_rating  \
# hospital_overall_rating                                   1.000000
# emergency_services                                       -0.159280
# hospital_type                                             0.133094
# mortality_national_comparison                            -0.009104
# safety_of_care_national_comparison                       -0.151785
# readmission_national_comparison                          -0.340240
# patient_experience_national_comparison                   -0.505543
# effectiveness_of_care_national_comparison                -0.029569
# timeliness_of_care_national_comparison                   -0.113658
#
#                                            emergency_services  hospital_type  \
# hospital_overall_rating                             -0.159280       0.133094
# emergency_services                                   1.000000      -0.046642
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(hospital_general_information_subset.corr(), annot = True, ax = ax)

# %% [markdown]
# #### Observations

# %% [markdown]
# The strongest negative relationship: hospital overall rating / patient experience national comparison with a -0.51 coefficient.
#
# On the other hand, the weakest negtaive relationship includes: hospital overall rating / effectiveness of care national comparison with a -0.03 correlation coefficient.
#
# The strongest positive relationship appears to be between hospital type / effectiveness of care national comparsion, hospital type / safety of care national comparison with a 0.61 correlation coefficient.
#
# In contrast, the weakest positive relationship includes: hopsital type / hospital overall rating with a 0.13 correlation coefficient

# %% [markdown]
# #### Scatterplot

# %%
# Create a scatterplot in seaborn illustrating the strong correlation listed above
sns.stripplot(data=hospital_general_information, x='hospital_type', y="effectiveness_of_care_national_comparison")
plt.show()

# %%
sns.stripplot(data=hospital_general_information, x="hospital_type", y="hospital_overall_rating", jitter=True)
plt.show()

# %% [markdown]
# #### Observations

# %%
#Because this data does not contain numeric values, a scatterplot is not the most useful visualization in determining relationships as these are more categorical data

# %% [markdown]
# #### Pair Plots

# %%
pair_plot = sns.pairplot(hospital_general_information_subset, vars=["hospital_overall_rating", "mortality_national_comparison", "readmission_national_comparison","readmission_national_comparison"])

# %% [markdown]
# ##### analyze further on hospital rating and readmission rates and hospital rating compared to mortality. Having a clear picture on these variables is useful in understanding the quality of various hospitals and how they compare.

# %% [markdown]
# #### Create a categorical plot

# %%
sns.set(style="ticks")
cat_plot_rating_vs_readmisson = sns.catplot(x="hospital_overall_rating", y="readmission_national_comparison", data=hospital_general_information)

# %% [markdown]
# It can be noted that for hospital ratings, if there is a rating of 5 the readmission rate is below the national average at a less frequent rate.
# On the other hand, a rating of 1 has an above the national average readmission rate at a less frequent rate.

# %%
sns.set(style="ticks")
sns.set(font_scale=0.6)
cat_plot_hospital_type_vs_patient_experience = sns.catplot(x="hospital_type", y="patient_experience_national_comparison", data=hospital_general_information)

# %%
sns.set(style="ticks")
sns.set(font_scale=.4)
cat_plot_hospital_ownership_vs_rating = sns.catplot(x="effectiveness_of_care_national_comparison", y="hospital_ownership", data=hospital_general_information)

# %% [markdown]
# #### Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.

# %% [markdown]
# ##### Does the rating of a hospital impact the readmission rate?
# Yes, the lower the rating of a hopsital, the more readmissions there are.

# %% [markdown]
# ##### How does the quality of care compare among the regions?
#
# Will assess this in future assignment

# %% [markdown]
# ##### How does the hospital ownership compare to a patient’s quality of care?
#
# Depending on the ownership of hospitals, the quality of care does differ. Further analysis is needed to uncover insights.

# %% [markdown]
# ##### Does region effect the mortality rate?
#
# Will assess this in future assignment

# %% [markdown]
# ##### How does the hospital type compare to a patient’s experience?
#
# There is no data available for children's hospitals. all types of hospitals have similar results, however critical access hospitals have slightly less frequent below national average values than other types.

# %% [markdown]
# ##### Additional Question
#
# How does hospital rating effect patient experience?

# %%
# Create a visualization of newly added question
sns.set(style="ticks")
sns.set(font_scale=0.6)
cat_plot_hospital_rating_vs_patient_experience = sns.catplot(x="hospital_overall_rating", y="patient_experience_national_comparison", data=hospital_general_information)

# %% [markdown]
# ##### The higest rating of 5, contains a higher number of above the national experience in terms of patient experience. There is no below the average listed for this rating. in contrast, the lowest rating of 1 contains a higher number of below the national average and no above national average.

# %% [markdown]
# #### Define any hypotheses that you can at this point. You’ll be testing these later on.

# %% [markdown]
# 1. If the overall hospital rating is high, then patient experiences are more likely to be above average.
# 2. If the hospital rating is low, then there is more readmission rates.

# %%
hospital_general_information_subset.to_csv(os.path.join(path, 'Data','Prepared Data', 'hospital_general_information_subset.csv'))
